# %%
# ================================
# Google Drive Setup
# ================================

from google.colab import drive
drive.mount('/content/drive')

import os

DRIVE_RUNS = "/content/drive/MyDrive/ML_Projects/Road_Damage_Detection/runs"

os.makedirs(DRIVE_RUNS, exist_ok=True)

# Connect Colab's /content/runs to Google Drive
if os.path.islink("/content/runs") or os.path.exists("/content/runs"):
    # !rm -rf /content/runs

# !ln -s "/content/drive/MyDrive/ML_Projects/Road_Damage_Detection/runs" /content/runs

print("✅ YOLO runs folder is connected to Google Drive")
print("📁", DRIVE_RUNS)
# Out:
# Mounted at /content/drive
# ✅ YOLO runs folder is connected to Google Drive
# 📁 /content/drive/MyDrive/ML_Projects/Road_Damage_Detection/runs

# %%
# !nvidia-smi
# Out:
# Tue Sep  8 00:12:48 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 7.8 MB/s eta 0:00:00
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.143 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.3/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="mbvuB9uRXXXX0UmuenjO")
# project = rf.workspace("majjj-vinay-kumar").project("rdd-india-1pbjf")
# version = project.version(1)
# dataset = version.download("yolov8")
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5dd11w5SH5zhbp1YP8PB")
project = rf.workspace("o230861-majji-vinay-kumar").project("final_img-nahsr")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typer
#     Found existing installation: typer 0.27.1
#     Uninstalling typer-0.27.1:
#       Successfully uninstalled typer-0.27.1
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Final_img-1 in yolov8:: 100%|██████████| 6098/6098 [00:00<00:00, 7072.42it/s]

# %% [markdown]
# ## Train model

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100 imgsz=720 plots=True patience=20
# Out:
# ...
# Ultralytics 8.4.143 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# %cd {HOME}
# Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %%
# Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %%
# Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source='/content/roaddamage2.jpeg' save=True

# %% [markdown]
# ## Validate Custom Model

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train-3/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.4.143 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 72 layers, 11,129,841 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1951.3±334.7 MB/s, size: 45.0 KB)
# val: Scanning /content/Final_img-1/valid/labels.cache... 305 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 305/305 58.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 2.6it/s 7.8s
#                    all        305       3307      0.581      0.293      0.314      0.184
#                    D00         36         50      0.136       0.02     0.0402     0.0211
#                    D20         63         76      0.255     0.0658     0.0935     0.0278
#                    D40         47        108      0.168      0.111     0.0704     0.0162
#                    D44         25         29          1          0      0.119     0.0451
# ...

# %%
# !zip -r my_folder.zip /content/runs
